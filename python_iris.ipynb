# %%
import sys
# !{sys.executable} -m pip install scikit-learn pandas seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: C:\Users\dxnie\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting scikit-learn
#   Using cached scikit_learn-1.9.1-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pandas
#   Using cached pandas-3.0.5-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (2.5.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.18.1)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Using cached joblib-1.6.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (3.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dxnie\appdata\local\programs\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2026.4)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Using cached matplotlib-3.11.2-cp312-cp312-win_amd64.whl.metadata (80 kB)
# Requirement already satisfied: cloudpickle>=3.0 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached contourpy-1.4.0-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\dxnie\appdata\local\programs\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\dxnie\appdata\local\programs\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached scikit_learn-1.9.1-cp312-cp312-win_amd64.whl (8.3 MB)
# Using cached pandas-3.0.5-cp312-cp312-win_amd64.whl (9.8 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached joblib-1.6.0-py3-none-any.whl (306 kB)
# Using cached matplotlib-3.11.2-cp312-cp312-win_amd64.whl (9.3 MB)
# Using cached contourpy-1.4.0-cp312-cp312-win_amd64.whl (234 kB)
# Installing collected packages: joblib, contourpy, scikit-learn, pandas, matplotlib, seaborn
# Successfully installed contourpy-1.4.0 joblib-1.6.0 matplotlib-3.11.2 pandas-3.0.5 scikit-learn-1.9.1 seaborn-0.13.2

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
df.head()
# Out:
# -------------------------------------------------------
#
# ModuleNotFoundError   Traceback (most recent call last)
#
# Cell In[5], line 1
#
# ----> 1 from sklearn.datasets import load_iris
#
#       2 import pandas as pd
#
#       4 iris = load_iris()
#
#
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\dxnie\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.9.1)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (2.5.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (3.7.0)
# Requirement already satisfied: cloudpickle>=3.0 in c:\users\dxnie\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: C:\Users\dxnie\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
df.head()
# Out:
# -------------------------------------------------------
#
# ModuleNotFoundError   Traceback (most recent call last)
#
# Cell In[8], line 1
#
# ----> 1 from sklearn.datasets import load_iris
#
#       2 import pandas as pd
#
#       4 iris = load_iris()
#
#
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\dxnie\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\dxnie\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
import sys
# !{sys.executable} -m pip install scikit-learn pandas seaborn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.9.1-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pandas
#   Using cached pandas-3.0.5-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting numpy>=1.24.1 (from scikit-learn)
#   Using cached numpy-2.5.3-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.18.1-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Using cached joblib-1.6.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Using cached narwhals-2.26.0-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Using cached threadpoolctl-3.7.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dxnie\appdata\local\programs\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2026.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Using cached matplotlib-3.11.2-cp312-cp312-win_amd64.whl.metadata (80 kB)
# Collecting cloudpickle>=3.0 (from joblib>=1.4.0->scikit-learn)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached contourpy-1.4.0-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached fonttools-4.65.0-cp312-cp312-win_amd64.whl.metadata (127 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached kiwisolver-1.5.1-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\dxnie\appdata\local\programs\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Collecting pillow>=9 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pillow-12.3.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\dxnie\appdata\local\programs\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached scikit_learn-1.9.1-cp312-cp312-win_amd64.whl (8.3 MB)
# Using cached pandas-3.0.5-cp312-cp312-win_amd64.whl (9.8 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached joblib-1.6.0-py3-none-any.whl (306 kB)
# Using cached matplotlib-3.11.2-cp312-cp312-win_amd64.whl (9.3 MB)
# Using cached narwhals-2.26.0-py3-none-any.whl (474 kB)
# Using cached numpy-2.5.3-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached scipy-1.18.1-cp312-cp312-win_amd64.whl (36.7 MB)
# Using cached threadpoolctl-3.7.0-py3-none-any.whl (26 kB)
# Using cached tzdata-2026.4-py2.py3-none-any.whl (347 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached contourpy-1.4.0-cp312-cp312-win_amd64.whl (234 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.65.0-cp312-cp312-win_amd64.whl (2.5 MB)
# Using cached kiwisolver-1.5.1-cp312-cp312-win_amd64.whl (70 kB)
# Using cached pillow-12.3.0-cp312-cp312-win_amd64.whl (7.2 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: tzdata, threadpoolctl, pyparsing, pillow, numpy, narwhals, kiwisolver, fonttools, cycler, cloudpickle, scipy, pandas, joblib, contourpy, scikit-learn, matplotlib, seaborn
# Successfully installed cloudpickle-3.1.2 contourpy-1.4.0 cycler-0.12.1 fonttools-4.65.0 joblib-1.6.0 kiwisolver-1.5.1 matplotlib-3.11.2 narwhals-2.26.0 numpy-2.5.3 pandas-3.0.5 pillow-12.3.0 pyparsing-3.3.2 scikit-learn-1.9.1 scipy-1.18.1 seaborn-0.13.2 threadpoolctl-3.7.0 tzdata-2026.4
# WARNING: There was an error checking the latest version of pip.

# %%
import seaborn as sns
sns.pairplot(df, hue='species')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# findfont: Failed to find font weight normal for DejaVu Sans, now using 700.
